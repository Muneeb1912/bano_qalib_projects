# %% [markdown]
# # week_10_fastApi

# %%
import sys
# !{sys.executable} -m pip freeze > requirements.txt

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\muneeb\Desktop\bano_qabil_python

# %%
pip install fastapi uvicorn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile main.py
from fastapi import FastAPI
app = FastAPI()
@app.get("/")
def home():
    return {"message":"My FastAPI project is ready."}
@app.get("/student")
def student():
    return {"name":"ali","age":20,"course":"Python"}
@app.get("/teacher")
def teacher():
    return {"name":"muneeb","age":24,"course":"Python"}
# Out:
# Writing main.py
