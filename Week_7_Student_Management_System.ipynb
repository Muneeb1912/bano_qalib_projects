# %% [raw]
# # Week_7_Student_Management_System

# %%
class student_management_system:
    def __init__(self):
        self.students = []
    def add_student(self):
        print("\n===== Add Student =====")
        student_id=input("Enter Student ID: ").strip()
        name = input("Enter Student Name: ").strip().title()
        age = input("Enter Student Age: ").strip()
        course = input("Enter Course Name: ").strip().title()
        if student_id == "" or name == "" or age == "" or course == "":
            print("All Information is required.")
            return
        for student in self.students:
            if student["id"] == student_id:
                print("This Student ID Already Exits.")
                return
        student = {
            "id":student_id,
            "name":name,
            "age":age,
            "course":course
        }
        self.students.append(student)
        print("Student Add Successfully.")
    
    def update_student(self):
        print("\n===== Update Student =====")
        if len(self.students) == 0:
            print("No Student records are avialable.")
            return
        student_id = input("Enter Student ID to Update").strip()
        for student in self.students:
            if student["id"] == student_id:
                print(f"Studnet Found: {student["name"]}")

                new_name = input("Enter New Name: ").strip().title()
                new_age= input("Enter New Age: ").strip()
                new_course= input("Enter New Course: ").strip().title()

                if new_name == "" or new_age == "" or new_course == "":
                    print("New Information cann't be empty.")
                    return
                student["name"] = new_name
                student["age"] = new_age
                student["course"] = new_course

                print("Student Updated successfully.")
                return
        print("Student ID was not found")

    def view_students(self):
        print("\n===== All Students =====")
        if len(self.students) == 0:
            print("No Students records are avialable.")
            return
        for student in self.students:
            print(f"\nStudent ID: {student["id"]}")
            print(f"Name: {student["name"]}")
            print(f"Age: {student["age"]}")
            print(f"\nCourse: {student["course"]}")

# %%
system = student_management_system()
while True:
    print("\n===== Student Management System =====")
    print("\n1. Add Studnet")
    print("2. Update Student")
    print("3. View All Students")
    print("4. Exit")

    choice = input("Enter Your Choice: ").strip()

    if choice == "1":
        system.add_student()
    elif choice == "2":
        system.update_student()
    elif choice == "3":
        system.view_students()
    elif choice == "4":
        print("Student Management System closed.")
        break
    else:
        print("Invalid Choice, Enter 1, 2, 3, or 4.")
# Out:
# ===== Student Management System =====
#
# 1. Add Studnet
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter Your Choice:  1
# ===== Add Student =====
# Enter Student ID:  01
# Enter Student Name:  Muneebj
# Enter Student Age:  18
# Enter Course Name:  Data Science
# Student Add Successfully.
#
# ===== Student Management System =====
#
# 1. Add Studnet
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter Your Choice:  1
# ===== Add Student =====
# Enter Student ID:  02
# Enter Student Name:  Ali
# Enter Student Age:  21
# Enter Course Name:  Geology
# Student Add Successfully.
#
# ===== Student Management System =====
#
# 1. Add Studnet
# 2. Update Student
# 3. View All Students
# 4. Exit
# Enter Your Choice:  3
# ===== All Students =====
#
# Student ID: 01
# Name: Muneebj
# Age: 18
#
# Course: Data Science
#
# Student ID: 02
# Name: Ali
# Age: 21
#
# Course: Geology
#
# ===== Student Management System =====
#
# 1. Add Studnet
# 2. Update Student
# ...
